# %% [markdown]
# <a href="https://colab.research.google.com/github/aishwaryamahadev-stack/Intern-Data-Validation-System/blob/main/Password_Strength_Checker_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
def check_password_strength(password):
    reasons = []
    if len(password) < 8:
        reasons.append("Password must be at least 8 characters long.")
    if not re.search(r"\d", password):
        reasons.append("Password must contain at least one digit.")
    if not re.search(r"[!@#$%^&*(),.?\":{}|<>]", password):
        reasons.append("Password must contain at least one special character.")
    if not reasons:
        print("Strong Password ✅")
    else:
        print("Weak Password ❌")
        for reason in reasons:
            print("Reason:", reason)
password_input = input("Enter your password: ")
check_password_strength(password_input)
