# %% [markdown]
# <a href="https://colab.research.google.com/github/aishwaryamahadev-stack/Intern-Data-Validation-System/blob/main/Inventory_Reorder_Checker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Enter number of products: "))

for i in range(1, n + 1):
    stock = int(input(f"Enter stock quantity for Product {i}: "))

    if stock < 20:
        print(f"Product {i}: Reorder Required")
    else:
        print(f"Product {i}: Stock Sufficient")
