# %% [markdown]
# <a href="https://colab.research.google.com/github/aishwaryamahadev-stack/Intern-Data-Validation-System/blob/main/Data_Usage_Alert_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
total_data = float(input("Enter total data limit (GB): "))
data_used = float(input("Enter data used (GB): "))
usage_percentage = (data_used / total_data) * 100
if usage_percentage >= 90:
    print("High Usage Alert")
elif usage_percentage >= 70 and usage_percentage < 90:
    print("Warning")
else:
    print("Normal Usage")
