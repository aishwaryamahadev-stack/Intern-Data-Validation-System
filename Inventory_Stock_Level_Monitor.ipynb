# %% [markdown]
# <a href="https://colab.research.google.com/github/aishwaryamahadev-stack/Intern-Data-Validation-System/blob/main/Inventory_Stock_Level_Monitor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
opening_stock = int(input("Enter opening stock: "))
items_sold = int(input("Enter items sold: "))
remaining_stock = opening_stock - items_sold
print("Remaining Stock:", remaining_stock)
if remaining_stock < 20:
    print("Reorder Required")
else:
    print("Stock Sufficient")
