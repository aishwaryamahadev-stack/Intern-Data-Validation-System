# %% [markdown]
# <a href="https://colab.research.google.com/github/aishwaryamahadev-stack/Intern-Data-Validation-System/blob/main/LinearRegressionmodelipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

data = {
    'area': [600, 800, 1000, 1200, 1400, 1600],
    'rooms': [1, 2, 2, 3, 3, 4],
    'price': [3000000, 4000000, 5000000, 6000000, 7000000, 8000000]
}

df = pd.DataFrame(data)

print(df)

X = df[['area', 'rooms']]
y = df['price']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("Mean Squared Error:", mse)
print("R^2 Score:", r2)
new_data = pd.DataFrame({'area': [1100], 'rooms': [3]})
predicted_price = model.predict(new_data)
print("\nPredicted price forarea=1100 sq ft and rooms=3:", int(predicted_price[0]))
